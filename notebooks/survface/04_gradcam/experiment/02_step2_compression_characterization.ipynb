# %% [markdown]
# # SurvFace Grad-CAM — 04. Compression and official open-set characterization
#
# training development에서 PCA/PQ를 학습하고 training calibration에서 threshold를 고정한 뒤 공식 gallery/mated/unmated 전체를 평가합니다.
#
# 이 노트북은 한 단계만 실행하는 thin runbook입니다. 계산 구현은 `research/experiments/step4_workflow.py`에 있습니다.

# %%
from __future__ import annotations

from pathlib import Path
import sys

import yaml

PROJECT_ROOT = Path.cwd().resolve()
for candidate in (PROJECT_ROOT, *PROJECT_ROOT.parents):
    if (candidate / "research").is_dir() and (candidate / "configs").is_dir():
        PROJECT_ROOT = candidate
        break
else:
    raise RuntimeError("프로젝트 루트(C:/ronbun)를 찾을 수 없습니다.")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

CONFIG_PATH = PROJECT_ROOT / "configs/experiments/step2_pytorch_gradcam.yaml"
CONFIG = yaml.safe_load(CONFIG_PATH.read_text(encoding="utf-8"))
EXECUTION = CONFIG["execution"]
MODEL_PROFILE = str(EXECUTION["model_profile"])
MODE = str(EXECUTION["mode"])
DATA_FRACTION = float(EXECUTION["data_fraction"])
EXECUTE_STAGE = bool(EXECUTION["execute_stage"])
WRITE_OUTPUTS = bool(EXECUTION["write_outputs"])
OVERWRITE = bool(EXECUTION["overwrite"])
DATASET_ID = "survface"

if MODE not in {"dev", "real"}:
    raise ValueError("MODE는 'dev' 또는 'real'이어야 합니다.")
if not 0.0 < DATA_FRACTION <= 1.0:
    raise ValueError("DATA_FRACTION은 (0, 1] 범위여야 합니다.")
if MODE == "real" and DATA_FRACTION != 1.0:
    raise ValueError("real 모드는 DATA_FRACTION=1.0이어야 합니다.")
if WRITE_OUTPUTS and not EXECUTE_STAGE:
    raise ValueError("WRITE_OUTPUTS=True이면 EXECUTE_STAGE도 True여야 합니다.")
if EXECUTE_STAGE and not WRITE_OUTPUTS:
    raise ValueError("정식 단계 실행은 WRITE_OUTPUTS=True여야 합니다.")

from research.experiments import characterize_step4_compression
from research.runtime import ProgressReporter

PROGRESS = ProgressReporter(
    "SurvFace Step 4 compression",
    heartbeat_seconds=None,
    milestone_percent=10,
)

# %%
if EXECUTE_STAGE:
    result = characterize_step4_compression(
        CONFIG_PATH,
        project_root=PROJECT_ROOT,
        dataset_id=DATASET_ID,
        execution_acknowledged=True,
        progress=PROGRESS.callback(key_prefix=f"{DATASET_ID}:step4:"),
    )
else:
    result = {
        "dataset_id": DATASET_ID,
        "status": "not_executed",
        "reason": "CONFIG execution gates are closed",
    }

result
# Out:
# [23:39:17] SurvFace Step 4 compression | survface compressor fit | elapsed=31s | progress=50% processed=5 total=10 rate=0.16/s eta=31s family=pca
# [23:39:27] SurvFace Step 4 compression | survface compressor fit | elapsed=41s | progress=60% processed=6 total=10 rate=0.15/s eta=27s family=pq profile=pq_512_m8_b8
# [23:39:46] SurvFace Step 4 compression | survface compressor fit | elapsed=1m 00s | progress=70% processed=7 total=10 rate=0.12/s eta=26s family=pq profile=pq_512_m16_b8
# [23:40:20] SurvFace Step 4 compression | survface compressor fit | elapsed=1m 34s | progress=80% processed=8 total=10 rate=0.08/s eta=24s family=pq profile=pq_512_m32_b8
# [23:41:28] SurvFace Step 4 compression | survface compressor fit | elapsed=2m 42s | progress=90% processed=9 total=10 rate=0.06/s eta=18s family=pq profile=pq_512_m64_b8
# [23:43:32] SurvFace Step 4 compression | survface compressor fit | elapsed=4m 46s | progress=100% processed=10 total=10 rate=0.03/s eta=0s family=pq profile=pq_512_m128_b8
# [23:45:11] SurvFace Step 4 compression | survface compression retrieval | elapsed=6m 25s | progress=10% processed=453284 total=4532840 rate=1177.50/s eta=57m 45s profile=pca_384 split=evaluation representation=compressed
# [23:46:52] SurvFace Step 4 compression | survface compression retrieval | elapsed=8m 06s | progress=20% processed=906568 total=4532840 rate=1866.78/s eta=32m 23s profile=pca_256 split=evaluation representation=compressed
# [23:48:29] SurvFace Step 4 compression | survface compression retrieval | elapsed=9m 43s | progress=30% processed=1359852 total=4532840 rate=2331.23/s eta=22m 41s profile=pca_128 split=evaluation representation=compressed
# [23:50:09] SurvFace Step 4 compression | survface compression retrieval | elapsed=11m 23s | progress=40% processed=1813136 total=4532840 rate=2654.31/s eta=17m 05s profile=pca_64 split=evaluation representation=compressed
# [23:51:47] SurvFace Step 4 compression | survface compression retrieval | elapsed=13m 01s | progress=50% processed=2266420 total=4532840 rate=2903.61/s eta=13m 01s profile=pca_32 split=evaluation representation=compressed
# [23:53:43] SurvFace Step 4 compression | survface compression retrieval | elapsed=14m 57s | progress=60% processed=2719704 total=4532840 rate=3033.51/s eta=9m 58s profile=pq_512_m8_b8 split=evaluation representation=compressed
# [23:55:33] SurvFace Step 4 compression | survface compression retrieval | elapsed=16m 47s | progress=70% processed=3172988 total=4532840 rate=3150.06/s eta=7m 12s profile=pq_512_m16_b8 split=evaluation representation=compressed
# [23:57:26] SurvFace Step 4 compression | survface compression retrieval | elapsed=18m 40s | progress=80% processed=3626272 total=4532840 rate=3236.74/s eta=4m 40s profile=pq_512_m32_b8 split=evaluation representation=compressed
# [23:59:15] SurvFace Step 4 compression | survface compression retrieval | elapsed=20m 29s | progress=90% processed=4079556 total=4532840 rate=3318.94/s eta=2m 17s profile=pq_512_m64_b8 split=evaluation representation=compressed
# [00:01:13] SurvFace Step 4 compression | survface compression retrieval | elapsed=22m 27s | progress=100% processed=4532840 total=4532840 rate=3364.46/s eta=0s profile=pq_512_m128_b8 split=evaluation representation=compressed
# {'run_id': '20260729-R001-cccb59d5',
#  'dataset_id': 'survface',
#  'paired_rows': 4633410,
#  'retrieval_rows': 3643180,
#  'next_stage': '05_saliency_compression_join'}

# %% [markdown]
# ## 다음 단계
#
# 다음은 `03_saliency_compression_join.ipynb`입니다.
#
# 커널을 재시작한 뒤 다음 노트북을 위에서 아래로 실행합니다.
